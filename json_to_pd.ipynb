# %%
import json
import pandas as pd

with open('data/female_players_part1.json') as json_file:
    dicta = json.load(json_file)
    player_data = dicta["data"][0]
#    with open('test.json', 'w') as write_file:
#        write_file.write(json.dumps(player_data))

# %%
player_list_dict = []
for player in player_data:
    player_list_dict.append(player['data'])
df = pd.DataFrame(player_list_dict)
print(df.columns)
# Out:
# Index(['vw_profiles___player_id', 'vw_profiles___player_id_raw',
#        'vw_profiles___name', 'vw_profiles___name_raw',
#        'vw_profiles___assoc_raw', 'vw_profiles___assoc',
#        'vw_profiles___gender', 'vw_profiles___gender_raw', 'vw_profiles___dob',
#        'vw_profiles___dob_raw', 'vw_profiles___age', 'vw_profiles___age_raw',
#        'vw_profiles___activity', 'vw_profiles___activity_raw',
#        'vw_profiles___handness', 'vw_profiles___handness_raw',
#        'vw_profiles___style', 'vw_profiles___style_raw', 'vw_profiles___grip',
#        'vw_profiles___grip_raw', 'vw_profiles___Totalmatches',
#        'vw_profiles___Totalmatches_raw', 'vw_profiles___Totalwins',
#        'vw_profiles___Totalwins_raw', 'vw_profiles___Totalloses',
#        'vw_profiles___Totalloses_raw', 'vw_profiles___Yearmatches',
#        'vw_profiles___Yearmatches_raw', 'vw_profiles___Yearwins',
#        'vw_profiles___Yearwins_raw', 'vw_profiles___Yearloses',
# ...

# %%
df = df.drop(
    columns=[
        'vw_profiles___player_id',
        'vw_profiles___name',
        'vw_profiles___assoc_raw',
        'vw_profiles___gender_raw',
        'vw_profiles___dob_raw',
        'vw_profiles___age_raw',
        "vw_profiles___age",
        'vw_profiles___activity_raw',
        'vw_profiles___handness',
        "vw_profiles___style",
        "vw_profiles___grip",
        "vw_profiles___Totalmatches",
        "vw_profiles___Totalwins",
        "vw_profiles___Totalloses",
        "vw_profiles___Yearmatches",
        "vw_profiles___Yearwins",
        "vw_profiles___Yearloses",
        "vw_profiles___WTTC",
        "vw_profiles___WTTC_raw",
        "slug",
        "__pk_val",'fabrik_select',
       'fabrik_view_url', 
       'fabrik_edit_url', 
       'fabrik_view', 
       'fabrik_edit',
       'fabrik_actions'

    ])

# %%
df.head()
# Out:
#   vw_profiles___player_id_raw vw_profiles___name_raw  \
# 0                      113207          A'ASA Junella
# 1                      145778      AALTONEN Gabriela
# 2                      100004          AALTONEN Nina
# 3                      131033     AARONS HUGHES Ruth
# 4                      145022          AARRAD Wahiba
#
#         vw_profiles___assoc vw_profiles___gender vw_profiles___dob  \
# 0            AMERICAN SAMOA               Female        1976-06-08
# 1                    SWEDEN               Female        2009-03-31
# 2                   FINLAND               Female        1981-01-26
# 3  UNITED STATES OF AMERICA               Female              None
# 4                   MOROCCO               Female        2003-03-16
#
#   vw_profiles___activity vw_profiles___handness_raw vw_profiles___style_raw  \
# 0                      T                          -                       -
# 1                      T                         RH                       A
# ...

# %%
df
# Out:
#     vw_profiles___player_id_raw vw_profiles___name_raw  \
# 0                        113207          A'ASA Junella
# 1                        145778      AALTONEN Gabriela
# 2                        100004          AALTONEN Nina
# 3                        131033     AARONS HUGHES Ruth
# 4                        145022          AARRAD Wahiba
# ..                          ...                    ...
# 495                      131345       ALMAZROUEI Amira
# 496                      131346      ALMAZROUEI Shamma
# 497                      130912       ALMBORG Signhild
# 498                      130911           ALMBORG Svea
# 499                      113519         ALMEDO Adriana
#
#           vw_profiles___assoc vw_profiles___gender vw_profiles___dob  \
# 0              AMERICAN SAMOA               Female        1976-06-08
# 1                      SWEDEN               Female        2009-03-31
# 2                     FINLAND               Female        1981-01-26
# ...
